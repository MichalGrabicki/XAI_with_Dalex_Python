# %%
# Explanatory variable: "Poland - GVA construction, LCU - Millions - Polish Zloty - SA - Annual"

# %%
# Loading libraries
import pandas as pd

# %%
# Loading data
filename = 'Poland_Macro_History.csv'
data_location = ''
data_raw = pd.read_csv(data_location + filename, sep=',')

# %%
# Chcecking imported data 
data_raw.head()
# Out:
#    Concept  Gross capital formation % of GDP  \
# 0  1976-01                         20.908712
# 1  1976-02                         20.876663
# 2  1976-03                         20.856755
# 3  1976-04                         20.847756
# 4  1976-05                         20.848436
#
#    Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)  \
# 0                                           0.806769
# 1                                           0.812642
# 2                                           0.819634
# 3                                           0.827065
# 4                                           0.834257
#
#    Arms imports (SIPRI trend indicator values)  \
# 0                                  748412949.3
# 1                                  746831393.5
# 2                                  748686554.9
# 3                                  753670048.8
# 4                                  761473490.2
#
# ...

# %%
data_raw.tail()
# Out:
#      Concept  Gross capital formation % of GDP  \
# 512  2018-09                         20.482422
# 513  2018-10                         20.365025
# 514  2018-11                         20.234030
# 515  2018-12                         20.090374
# 516  2019-01                         20.780933
#
#      Merchandise imports from low- and middle-income economies in South Asia (% of total merchandise imports)  \
# 512                                           0.939736
# 513                                           0.964070
# 514                                           0.995868
# 515                                           1.035697
# 516                                           0.787964
#
#      Arms imports (SIPRI trend indicator values)  \
# 512                                 1.429908e+08
# 513                                 1.662734e+08
# 514                                 1.940333e+08
# 515                                 2.266003e+08
# ...

# %%
# Replacing space from column names with "_" and removing "-" 
data_raw.columns = data_raw.columns.str.replace(' ', '_')
data_raw.columns = data_raw.columns.str.replace('-', '')

# %%
# Chcecking data structure
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 38 columns):
#  #   Column                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                       --------------  -----
#  0   Concept                                                                                                      517 non-null    object
#  1   Gross_capital_formation_%_of_GDP                                                                             517 non-null    float64
#  2   Merchandise_imports_from_low_and_middleincome_economies_in_South_Asia_(%_of_total_merchandise_imports)       517 non-null    float64
#  3   Arms_imports_(SIPRI_trend_indicator_values)                                                                  517 non-null    float64
# ...

# %%
# Changin date coloumn name and type
data_raw['Concept']= pd.to_datetime(data_raw['Concept'])
data_raw = data_raw.rename(columns={'Concept':'Date_key'})

# %%
data_raw.head()
# Out:
#     Date_key  Gross_capital_formation_%_of_GDP  \
# 0 1976-01-01                         20.908712
# 1 1976-02-01                         20.876663
# 2 1976-03-01                         20.856755
# 3 1976-04-01                         20.847756
# 4 1976-05-01                         20.848436
#
#    Merchandise_imports_from_low_and_middleincome_economies_in_South_Asia_(%_of_total_merchandise_imports)  \
# 0                                           0.806769
# 1                                           0.812642
# 2                                           0.819634
# 3                                           0.827065
# 4                                           0.834257
#
#    Arms_imports_(SIPRI_trend_indicator_values)  \
# 0                                  748412949.3
# 1                                  746831393.5
# 2                                  748686554.9
# 3                                  753670048.8
# 4                                  761473490.2
#
# ...

# %%
# Chcecking data structure
data_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 38 columns):
#  #   Column                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                       --------------  -----
#  0   Date_key                                                                                                     517 non-null    datetime64[ns]
#  1   Gross_capital_formation_%_of_GDP                                                                             517 non-null    float64
#  2   Merchandise_imports_from_low_and_middleincome_economies_in_South_Asia_(%_of_total_merchandise_imports)       517 non-null    float64
#  3   Arms_imports_(SIPRI_trend_indicator_values)                                                                  517 non-null    float64
# ...

# %%
# Saving cleaned data 
data_raw.to_csv('data_clean.csv')
